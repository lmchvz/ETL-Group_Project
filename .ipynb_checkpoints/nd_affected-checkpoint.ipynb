# %%
# Import Libraries
import pandas as pd

# %%
# Import CSV file into DataFrame
wd_affected = pd.read_csv('./Resources/wd-total-affected-natural-disasters.csv', sep=';')

wd_affected.head()
# Out:
#   Country Code    Country Name      2014     2013       2012       2011  \
# 0          AFG     AFGHANISTAN  120000.0  21628.0    51501.0  1762815.0
# 1          ALB         ALBANIA       NaN      NaN   230000.0        NaN
# 2          DZA         ALGERIA       NaN      NaN      101.0      793.0
# 3          ASM  AMERICAN SAMOA       NaN      NaN        NaN        NaN
# 4          AGO          ANGOLA       NaN   1000.0  1833900.0    90684.0
#
#        2010      2009      2008     2007  ...  1909  1908  1907  1906  1905  \
# 0   46200.0   65857.0  452964.0  30255.0  ...   NaN   NaN   NaN   NaN   NaN
# 1   14000.0    6750.0       NaN    225.0  ...   NaN   NaN   NaN   NaN   NaN
# 2      43.0    2548.0   59050.0   1305.0  ...   NaN   NaN   NaN   NaN   NaN
# 3       NaN    2500.0       NaN      NaN  ...   NaN   NaN   NaN   NaN   NaN
# 4  189781.0  251003.0   98837.0  64343.0  ...   NaN   NaN   NaN   NaN   NaN
#
#    1904  1903  1902  1901  1900
# 0   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 117 columns]

# %%
# Drop first two colunns to make a List of Column Names 
year_df = wd_affected.drop(wd_affected.columns[[0, 1]], axis=1)

# Create List of Column Names 
column_names = list(year_df.columns.values)
column_names
# Out:
# ['2014',
#  '2013',
#  '2012',
#  '2011',
#  '2010',
#  '2009',
#  '2008',
#  '2007',
#  '2006',
#  '2005',
#  '2004',
#  '2003',
#  '2002',
#  '2001',
#  '2000',
#  '1999',
#  '1998',
#  '1997',
#  '1996',
#  '1995',
#  '1994',
#  '1993',
#  '1992',
#  '1991',
#  '1990',
#  '1989',
#  '1988',
#  '1987',
#  '1986',
#  '1985',
#  '1984',
#  '1983',
#  '1982',
#  '1981',
#  '1980',
#  '1979',
#  '1978',
#  '1977',
#  '1976',
#  '1975',
#  '1974',
#  '1973',
#  '1972',
#  '1971',
#  '1970',
#  '1969',
#  '1968',
#  '1967',
#  '1966',
#  '1965',
#  '1964',
#  '1963',
#  '1962',
#  '1961',
#  '1960',
#  '1959',
#  '1958',
#  '1957',
#  '1956',
#  '1955',
#  '1954',
#  '1953',
#  '1952',
#  '1951',
#  '1950',
#  '1949',
#  '1948',
#  '1947',
#  '1946',
#  '1945',
#  '1944',
#  '1943',
#  '1942',
#  '1941',
#  '1940',
#  '1939',
#  '1938',
#  '1937',
#  '1936',
#  '1935',
#  '1934',
#  '1933',
#  '1932',
#  '1931',
#  '1930',
#  '1929',
#  '1928',
#  '1927',
#  '1926',
#  '1925',
#  '1924',
#  '1923',
#  '1922',
#  '1921',
#  '1920',
#  '1919',
#  '1918',
#  '1917',
#  '1916',
#  '1915',
#  '1914',
#  '1913',
#  '1912',
#  '1911',
#  '1910',
#  '1909',
#  '1908',
#  '1907',
#  '1906',
#  '1905',
#  '1904',
#  '1903',
#  '1902',
#  '1901',
#  '1900']

# %%
# Use Pandas Melt to combine Columns Names into one "Year" Column 
meltDF = pd.melt(wd_affected,
                 id_vars=['Country Code',
                          'Country Name'],
                  value_vars= column_names ,
                  var_name='Year')
meltDF.head()
# Out:
#   Country Code    Country Name  Year     value
# 0          AFG     AFGHANISTAN  2014  120000.0
# 1          ALB         ALBANIA  2014       NaN
# 2          DZA         ALGERIA  2014       NaN
# 3          ASM  AMERICAN SAMOA  2014       NaN
# 4          AGO          ANGOLA  2014       NaN

# %%
# Drop First Two Columns Again 
meltDF = meltDF.drop(['Country Code', 'Country Name'], axis = 1)

# Groupby Year and use Sum Function to Total year counts 
meltDF = meltDF.groupby("Year").value.sum().reset_index()

meltDF
# Out:
#      Year        value
# 0    1900          0.0
# 1    1901          0.0
# 2    1902          0.0
# 3    1903         23.0
# 4    1904          0.0
# ..    ...          ...
# 110  2010  257890131.0
# 111  2011  212695321.0
# 112  2012  107528037.0
# 113  2013   96538033.0
# 114  2014    4277104.0
#
# [115 rows x 2 columns]
