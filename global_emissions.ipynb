# %%
# Import Libraries
import pandas as pd

# %%
# Import CSV file into DataFrame
wd_emissions = pd.read_csv('./Resources/wd-fossil-fuel-emissions.csv')
wd_emissions.head()
# Out:
#    Year  Total  Gas  Liquids  Solids  Production  Flaring  Capita
# 0  1751      3    0        0       3           0        0     NaN
# 1  1752      3    0        0       3           0        0     NaN
# 2  1753      3    0        0       3           0        0     NaN
# 3  1754      3    0        0       3           0        0     NaN
# 4  1755      3    0        0       3           0        0     NaN

# %%
emissions_df = wd_emissions[['Year','Total']]
emissions_df = emissions_df.rename(columns={'Total': 'Emissions'})

emissions_df.head()
# Out:
#    Year  Emissions
# 0  1751          3
# 1  1752          3
# 2  1753          3
# 3  1754          3
# 4  1755          3

# %%
#To select rows whose column value is in list 
emissions_df = emissions_df[(emissions_df.Year >= 1900) & (emissions_df.Year <= 2014)]
emissions_df
# Out:
#      Year  Emissions
# 149  1900        534
# 150  1901        552
# 151  1902        566
# 152  1903        617
# 153  1904        624
# ..    ...        ...
# 258  2009       8641
# 259  2010       9137
# 260  2011       9508
# 261  2012       9671
# 262  2013       9776
#
# [114 rows x 2 columns]

# %%
df.loc['2014-01-01':'2014-02-01']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-876e733b0334> in <module>
#       1 from_ts = '2012'
#       2 to_ts = '2013'
# ----> 3 wd_emissions = wd_emissions[(wd_emissions['Year'] < from_ts) | (wd_emissions['Year'] > to_ts)]
#       4 wd_emissions
#
# //anaconda2/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# //anaconda2/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1115                     result = method(y)
#    1116                 if result is NotImplemented:
# -> 1117                     return invalid_comparison(x, y, op)
#    1118             else:
#    1119                 result = op(x, y)
#
# //anaconda2/lib/python3.7/site-packages/pandas/core/ops/__init__.py in invalid_comparison(left, right, op)
#     495         raise TypeError(
#     496             "Invalid comparison between dtype={dtype} and {typ}".format(
# --> 497                 dtype=left.dtype, typ=type(right).__name__
#     498             )
#     499         )
#
# TypeError: Invalid comparison between dtype=int64 and str
